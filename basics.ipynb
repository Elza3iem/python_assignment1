# %%
my_name="mohamed"
my_age=22
my_height=1.75
is_student= True
print(f"my name is: {my_name} , my age is:{22}, my height is:{1.75} and my studying state is:{is_student}")
# Out:
# my name is: mohamed , my age is:22, my height is:1.75 and my studying state is:True

# %%
var_1=int(input("enter the first integer"))
var_2=int(input("enter the second integer"))
sum_vars=var_1+var_2
product=var_1*var_2
diffrence=var_1-var_2
if(var_1>var_2):
    print("var_1 is greater than var_2")
elif(var_1<var_2):
    print("var_1 is smaller than var_2")
else: print("the two variables are equal")
print(f"the summation of the vars={sum_vars} \nthe product of vars={product} \nthe diffrence of them={diffrence}")
# Out:
# enter the first integer 5
# enter the second integer 7
# var_1 is smaller than var_2
# the summation of the vars=12
# the product of vars=35
# the diffrence of them=-2

# %%
your_grade=(int(input("Enter your grade:")))
if (your_grade>=90):
    print("excellent")
elif(your_grade>=75 and your_grade<=89):
    print("very good")
elif(your_grade>=60 and your_grade<=74):
    print("good")
else: print("you needs improvement")
# Out:
# Enter your grade: 60
# good

# %%
names = ["Ahmed", "Sara", "Mohamed"]
ages = [22, 20, 25]
print("Name       | Age")
print("-" * 18)
for name, age in zip(names, ages): # we used zip to unpack the things that stored inside the array
    print(f"{name:<10} | {age}") # i tried all the number until reached 10 is sutable
# Out:
# Name       | Age
# ------------------
# Ahmed      | 22
# Sara       | 20
# Mohamed    | 25
